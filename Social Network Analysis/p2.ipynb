# %% [markdown]
# # Social Network Analysis - Assignment 2
# ---
#
# > Department of Management Science and Technology <br />
# > Athens University of Economics and Business <br />
#
# > Panagiota Gkourioti - P2822109 <br />

# %% [markdown]
# ## Import and pre-process the dataset

# %%
# load necessary packages
import pandas as pd
import gzip
import numpy as np
from collections import Counter
from itertools import combinations

# %%
# Read the data
authors = pd.read_csv('authors.csv.gz', compression='gzip', encoding='utf8', sep=',', names=["YEAR", "TITLE", "CONFERENCE", "AUTHORS"])
authors
# Out:
#          YEAR                                              TITLE  \
# 0        1998  The Future of Classic Data Administration: Obj...
# 1        1974    Seven Steps to Rendezvous with the Casual User.
# 2        1991                        The LILOG Inference Engine.
# 3        1991  Why a Hill Can't be a Valley: Representing Ges...
# 4        1993  Towards Flexible Distributed Information Retri...
# ...       ...                                                ...
# 2793923  2009  Adaptive Scheduling for QoS Virtual Machines u...
# 2793924  2001  An Integrated Approach to Parallel Scheduling ...
# 2793925  1997  A Historical Application Profiler for Use by P...
# 2793926  2016          Open Issues in Cloud Resource Management.
# 2793927  2002          Job Scheduling for the BlueGene/L System.
#
#                                            CONFERENCE  \
# 0                                                SWEE
# 1        IFIP Working Conference Data Base Management
# 2                         Text Understanding in LILOG
# 3                         Text Understanding in LILOG
# 4                           Advanced Database Systems
# ...                                               ...
# 2793923                                         JSSPP
# 2793924                                         JSSPP
# 2793925                                         JSSPP
# 2793926                                         JSSPP
# 2793927                                         JSSPP
#
#                                                    AUTHORS
# 0                                          Arnon Rosenthal
# 1                                               E. F. Codd
# 2                    Toni Bollinger,Sven Lorenz,Udo Pletat
# 3                      Kai-Uwe Carstensen,Geoffrey Simmons
# 4                             David W. Flater,Yelena Yesha
# ...                                                    ...
# 2793923                                    Angela C. Sodan
# 2793924  Yanyong Zhang,Hubertus Franke,José E. Moreira,...
# 2793925                                    Richard Gibbons
# 2793926                       Narayan Desai,Walfredo Cirne
# 2793927       Elie Krevat,José G. Castaños,José E. Moreira
#
# [2793928 rows x 4 columns]

# %%
# Check for missing values
print(" \nCount of missing values in authors dataset: \n\n", authors.isnull().sum())
# Out:
#
# Count of missing values in authors dataset:
#
#  YEAR             0
# TITLE            0
# CONFERENCE       0
# AUTHORS       3877
# dtype: int64

# %%
# Filter out records not related to conferences “CIKM”, “KDD”, “ICWSM”, “WWW” and “IEEE BigData” or older than 5 years
authors_df = authors[authors['CONFERENCE'].isin(["CIKM", "KDD", "ICWSM", "WWW", "IEEE BigData"])&
                     authors['YEAR'].isin([2016, 2017, 2018, 2019, 2020])]
authors_df
# Out:
#          YEAR                                              TITLE CONFERENCE  \
# 133406   2017  Public Transportation Mode Detection from Cell...       CIKM
# 133407   2019  DSANet: Dual Self-Attention Network for Multiv...       CIKM
# 133409   2020  Multi-task Adversarial Spatial-Temporal Networ...       CIKM
# 133412   2020  A Framework for Analyzing the Impact of Missin...       CIKM
# 133417   2020  Auxiliary-task Based Deep Reinforcement Learni...       CIKM
# ...       ...                                                ...        ...
# 2471761  2020  GeoSiteSearch: A Tool to Map Vietnamese Diaspo...      ICWSM
# 2471762  2020  Auditing Race and Gender Discrimination in Onl...      ICWSM
# 2471763  2020  Driving the Last Mile: Characterizing and Unde...      ICWSM
# 2471765  2018  Automatically Conceptualizing Social Media Ana...      ICWSM
# 2471782  2016  Identifying Rhetorical Questions in Social Media.      ICWSM
#
#                                                    AUTHORS
# 133406   Guanyao Li,Chun-Jie Chen,Sheng-Yun Huang,Ai-Jo...
# 133407         Siteng Huang,Donglin Wang,Xuehan Wu,Ao Tang
# 133409        Senzhang Wang,Hao Miao,Hao Chen,Zhiqiu Huang
# 133412   Fabiola Santore,Eduardo Cunha de Almeida,Wagne...
# 133417   Wei Shen 0005,Xiaonan He,Chuheng Zhang,Qiang N...
# ...                                                    ...
# 2471761   Madison G. Masten,Thien-Huong Ninh,Nicholas Tran
# 2471762  Joshua Asplund,Motahhare Eslami,Hari Sundaram,...
# 2471763  Hemank Lamba,Shashank Srikanth,Dheeraj Reddy P...
# 2471765  Soon-Gyo Jung,Joni O. Salminen,Jisun An,Haewoo...
# 2471782  Suhas Ranganath,Xia Hu,Jiliang Tang,Suhang Wan...
#
# [8721 rows x 4 columns]

# %%
# Drop missing values
authors_df = authors_df.dropna()
authors_df
# Out:
#          YEAR                                              TITLE CONFERENCE  \
# 133406   2017  Public Transportation Mode Detection from Cell...       CIKM
# 133407   2019  DSANet: Dual Self-Attention Network for Multiv...       CIKM
# 133409   2020  Multi-task Adversarial Spatial-Temporal Networ...       CIKM
# 133412   2020  A Framework for Analyzing the Impact of Missin...       CIKM
# 133417   2020  Auxiliary-task Based Deep Reinforcement Learni...       CIKM
# ...       ...                                                ...        ...
# 2471761  2020  GeoSiteSearch: A Tool to Map Vietnamese Diaspo...      ICWSM
# 2471762  2020  Auditing Race and Gender Discrimination in Onl...      ICWSM
# 2471763  2020  Driving the Last Mile: Characterizing and Unde...      ICWSM
# 2471765  2018  Automatically Conceptualizing Social Media Ana...      ICWSM
# 2471782  2016  Identifying Rhetorical Questions in Social Media.      ICWSM
#
#                                                    AUTHORS
# 133406   Guanyao Li,Chun-Jie Chen,Sheng-Yun Huang,Ai-Jo...
# 133407         Siteng Huang,Donglin Wang,Xuehan Wu,Ao Tang
# 133409        Senzhang Wang,Hao Miao,Hao Chen,Zhiqiu Huang
# 133412   Fabiola Santore,Eduardo Cunha de Almeida,Wagne...
# 133417   Wei Shen 0005,Xiaonan He,Chuheng Zhang,Qiang N...
# ...                                                    ...
# 2471761   Madison G. Masten,Thien-Huong Ninh,Nicholas Tran
# 2471762  Joshua Asplund,Motahhare Eslami,Hari Sundaram,...
# 2471763  Hemank Lamba,Shashank Srikanth,Dheeraj Reddy P...
# 2471765  Soon-Gyo Jung,Joni O. Salminen,Jisun An,Haewoo...
# 2471782  Suhas Ranganath,Xia Hu,Jiliang Tang,Suhang Wan...
#
# [8720 rows x 4 columns]

# %%
# Sort by year
authors_df = authors_df.sort_values(by=['YEAR'])
# Fix indexing
authors_df.index = np.arange(1, len(authors_df)+1)
authors_df
# Out:
#       YEAR                                              TITLE    CONFERENCE  \
# 1     2016  Identifying Rhetorical Questions in Social Media.         ICWSM
# 2     2016  Shooting a moving target: Motion-prediction-ba...  IEEE BigData
# 3     2016  A low-load stream processing scheme for IoT en...  IEEE BigData
# 4     2016  Framing Mobile Information Needs: An Investiga...          CIKM
# 5     2016  Using big data to enhance the bosch production...  IEEE BigData
# ...    ...                                                ...           ...
# 8716  2020  Neural Network Training Techniques Regularize ...  IEEE BigData
# 8717  2020       Sample Optimization For Display Advertising.          CIKM
# 8718  2020  Analysis and Classification of Vaccine Dialogu...  IEEE BigData
# 8719  2020  TinyGNN: Learning Efficient Graph Neural Netwo...           KDD
# 8720  2020  Self-Supervised Audio-Visual Representation Le...  IEEE BigData
#
#                                                 AUTHORS
# 1     Suhas Ranganath,Xia Hu,Jiliang Tang,Suhang Wan...
# 2     Yanan Bao,Huasen Wu,Tianxiao Zhang,Albara Ah R...
# 3                        Tomoki Yoshihisa,Takahiro Hara
# 4     Shuguang Han,Xing Yi,Zhen Yue,Zhigeng Geng,Aly...
# 5                      Ankita Mangal,Nishant Kumar 0006
# ...                                                 ...
# 8716                     Cheng Chen,Junjie Yang,Yi Zhou
# 8717  Hongliang Fei,Shulong Tan,Pengju Guo,Wenbo Zha...
# 8718                      Nijhum Paul,Swapna S. Gokhale
# 8719   Bencheng Yan,Chaokun Wang,Gaoyang Guo,Yunkai Lou
# 8720  Zishun Feng,Ming Tu,Rui Xia,Yuxuan Wang,Ashok ...
#
# [8720 rows x 4 columns]

# %% [markdown]
# ## Find co-authorships for each year

# %%
# Create subset data frames for each year
authors_2016 = authors_df[authors_df['YEAR'] == 2016]
authors_2017 = authors_df[authors_df['YEAR'] == 2017]
authors_2018 = authors_df[authors_df['YEAR'] == 2018]
authors_2019 = authors_df[authors_df['YEAR'] == 2019]
authors_2020 = authors_df[authors_df['YEAR'] == 2020]

# %%
# Create dictionaries with authors
dict_2016 = {}
dict_2017 = {}
dict_2018 = {}
dict_2019 = {}
dict_2020 = {}

for idx in authors_2016.index:
    dict_2016.update({idx : authors_2016['AUTHORS'][idx].split(',')})

for idx in authors_2017.index:
    dict_2017.update({idx : authors_2017['AUTHORS'][idx].split(',')})

for idx in authors_2018.index:
    dict_2018.update({idx : authors_2018['AUTHORS'][idx].split(',')})

for idx in authors_2019.index:
    dict_2019.update({idx : authors_2019['AUTHORS'][idx].split(',')})
    
for idx in authors_2020.index:
    dict_2020.update({idx : authors_2020['AUTHORS'][idx].split(',')})

# %%
list_2016 = list(dict_2016.values())
list_2017 = list(dict_2017.values())
list_2018 = list(dict_2018.values())
list_2019 = list(dict_2019.values())
list_2020 = list(dict_2020.values())

# %%
# find most frequent pairs of authors for 2016
count_2016  = Counter()
for sub in list_2016:
    if len(list_2016) < 2:
        continue
    sub.sort()
    for comb in combinations(sub,2):
        count_2016[comb] += 1

print(count_2016.most_common())
# Out:
# [(('Huan Liu 0001', 'Jiliang Tang'), 6), (('Quanzhi Li', 'Rui Fang'), 6), (('Quanzhi Li', 'Sameena Shah'), 6), (('Rui Fang', 'Sameena Shah'), 6), (('Philip S. Yu', 'Sihong Xie'), 6), (('Armineh Nourbakhsh', 'Quanzhi Li'), 5), (('Armineh Nourbakhsh', 'Rui Fang'), 5), (('Armineh Nourbakhsh', 'Sameena Shah'), 5), (('Armineh Nourbakhsh', 'Xiaomo Liu'), 5), (('Quanzhi Li', 'Xiaomo Liu'), 5), (('Rui Fang', 'Xiaomo Liu'), 5), (('Sameena Shah', 'Xiaomo Liu'), 5), (('Chun-Ta Lu', 'Philip S. Yu'), 5), (('Alok N. Choudhary', 'Ankit Agrawal'), 5), (('Jiebo Luo', 'Tianran Hu'), 5), (('Jiawei Zhang 0001', 'Philip S. Yu'), 4), (('Alok N. Choudhary', 'Wei-keng Liao'), 4), (('Ankit Agrawal', 'Wei-keng Liao'), 4), (('Hengshu Zhu', 'Hui Xiong 0001'), 4), (('Nicholas Jing Yuan', 'Xing Xie 0001'), 4), (('Chuanren Liu', 'Hui Xiong 0001'), 4), (('Quan Z. Sheng', 'Xue Li 0001'), 4), (('Chao Huang 0001', 'Dong Wang 0002'), 4), (('Huan Liu 0001', 'Suhang Wang'), 3), (('Huan Liu 0001', 'Xia Hu'), 3), (('Jiliang Tang', 'Suhang Wang'), 3), (('Hông-Ân Cao', 'Karl Aberer'), 3), (('Hông-Ân Cao', 'Nuno Nunes 0001'), 3), (('Hông-Ân Cao', 'Tri Kurniawan Wijaya'), 3), (('Karl Aberer', 'Nuno Nunes 0001'), 3), (('Karl Aberer', 'Tri Kurniawan Wijaya'), 3), (('Nuno Nunes 0001', 'Tri Kurniawan Wijaya'), 3), (('Jiafeng Guo', 'Qingyao Ai'), 3), (('Jiafeng Guo', 'W. Bruce Croft'), 3), (('Qingyao Ai', 'W. Bruce Croft'), 3), (('Houping Xiao', 'Jing Gao 0004'), 3), (('Houping Xiao', 'Lu Su'), 3), (('Jing Gao 0004', 'Lu Su'), 3), (('Jing Gao 0004', 'Qi Li 0012'), 3), (('Adam Jatowt', 'Katsumi Tanaka'), 3), (('Jia Zeng', 'Mingxuan Yuan'), 3), (('Yudian Zheng', 'Zhipeng Huang 0001'), 3), (('Abid Hussain', 'Raghava Rao Mukkamala'), 3), (('Abid Hussain', 'Ravi Vatrapu'), 3), (('Raghava Rao Mukkamala', 'Ravi Vatrapu'), 3), (('Dawei Yin', 'Jiliang Tang'), 3), (('Dawei Yin', 'Yi Chang 0001'), 3), (('Jiliang Tang', 'Yi Chang 0001'), 3), (('A. Murat Ozbayoglu', 'Erdogan Dogdu'), 3), (('Jiawei Han 0001', 'Xiang Ren 0001'), 3), (('Allan N. Zhang', 'Rong Wen'), 3), (('Milad Makkie', 'Shannon Quinn'), 3), (('Milad Makkie', 'Tianming Liu'), 3), (('Milad Makkie', 'Xiang Li 0001'), 3), (('Shannon Quinn', 'Tianming Liu'), 3), (('Shannon Quinn', 'Xiang Li 0001'), 3), (('Tianming Liu', 'Xiang Li 0001'), 3), (('Hongfu Liu', 'Yun Fu 0001'), 3), (('Sheng Li 0001', 'Yun Fu 0001'), 3), (('Ting Zhu', 'Zhichuan Huang'), 3), (('Allan N. Zhang', 'Dazhi Yang'), 3), (('Allan N. Zhang', 'Gary S. W. Goh'), 3), (('Hongfeng Yu', 'Kwo-Sen Kuo'), 3), (('Hongfeng Yu', 'Thomas L. Clune'), 3), (('Kwo-Sen Kuo', 'Thomas L. Clune'), 3), (('Allan Hanbury', 'Mihai Lupu'), 3), (('Dhabaleswar K. Panda', 'Xiaoyi Lu'), 3), (('Lina Yao', 'Quan Z. Sheng'), 3), (('Quan Z. Sheng', 'Wei Emma Zhang'), 3), (('Jiebo Luo', 'Yu Wang 0041'), 3), (('Chunqiu Zeng', 'Qing Wang 0016'), 3), (('Chunqiu Zeng', 'Tao Li 0001'), 3), (('Qing Wang 0016', 'Tao Li 0001'), 3), (('Bee-Chung Chen', 'Deepak Agarwal'), 3), (('Enhong Chen', 'Qi Liu 0003'), 3), (('Joe Walsh', 'Rayid Ghani'), 3), (('Bing Liu 0001', 'Zhiyuan Chen 0001'), 3), (('Chang-Tien Lu', 'Naren Ramakrishnan'), 3), (('Hongbo Deng', 'Yi Chang 0001'), 3), (('Chenhao Tan', 'Lillian Lee'), 3), (('Bing Liu 0001', 'Shuai Wang 0020'), 3), (('Peng Cui 0001', 'Wenwu Zhu 0001'), 3), (('Deb Roy', 'Soroush Vosoughi'), 3), (('Jiliang Tang', 'Xia Hu'), 2), (('Huasen Wu', 'Xin Liu 0002'), 2), (('Huasen Wu', 'Yanan Bao'), 2), (('Xin Liu 0002', 'Yanan Bao'), 2), (('Bei Shi', 'Wai Lam'), 2), (('Chuanfei Xu', 'Yan Liu'), 2), (('Chuanfei Xu', 'Yongyi Xian'), 2), (('Yan Liu', 'Yongyi Xian'), 2), (('Chun-Ta Lu', 'Lifang He 0001'), 2), (('Chun-Ta Lu', 'Weixiang Shao'), 2), (('Lifang He 0001', 'Philip S. Yu'), 2), (('Philip S. Yu', 'Weixiang Shao'), 2), (('Vipin Kumar', 'Xiaowei Jia'), 2), (('Bonghee Hong', 'Jaegi Hong'), 2), (('Hanghang Tong', 'Jie Tang 0001'), 2), (('Allan Hanbury', 'Guido Zuccon'), 2), (('Allan Hanbury', 'João R. M. Palotti'), 2), (('Abdeltawab M. Hendawi', 'Nada Basit'), 2), (('Berkay  ...

# %%
# find most frequent pairs of authors for 2017
count_2017  = Counter()
for sub in list_2017:
    if len(list_2017) < 2:
        continue
    sub.sort()
    for comb in combinations(sub,2):
        count_2017[comb] += 1

print(count_2017.most_common())
# Out:
# [(('Bokai Cao', 'Philip S. Yu'), 6), (('Lifang He 0001', 'Philip S. Yu'), 6), (('Chao Zhang 0014', 'Jiawei Han 0001'), 6), (('Ben Y. Zhao', 'Haitao Zheng 0001'), 5), (('Chao Zhang 0014', 'Quan Yuan 0001'), 5), (('Jiawei Han 0001', 'Quan Yuan 0001'), 5), (('Elke A. Rundensteiner', 'Lei Cao 0004'), 5), (('Huan Liu 0001', 'Xia Hu'), 4), (('Jiawei Han 0001', 'Xiang Ren 0001'), 4), (('Chun-Ta Lu', 'Philip S. Yu'), 4), (('Depeng Jin', 'Yong Li 0008'), 4), (('Weinan Zhang 0001', 'Yong Yu 0001'), 4), (('Jiawei Zhang 0001', 'Philip S. Yu'), 4), (('Evgeny Kharlamov', 'Ian Horrocks'), 4), (('Jiebo Luo', 'Tianran Hu'), 3), (('Florian Lemmerich', 'Markus Strohmaier'), 3), (('Huan Liu 0001', 'Liang Wu 0006'), 3), (('Liang Wu 0006', 'Xia Hu'), 3), (('Ben Y. Zhao', 'Gang Wang 0011'), 3), (('Gang Wang 0011', 'Haitao Zheng 0001'), 3), (('Anuj Karpatne', 'Vipin Kumar'), 3), (('Jiawei Han 0001', 'Jingbo Shang'), 3), (('Huan Liu 0001', 'Suhang Wang'), 3), (('Huayu Li', 'Yong Ge'), 3), (('Hui Xiong 0001', 'Leilei Sun'), 3), (('Hanghang Tong', 'Nan Cao'), 3), (('Chenwei Zhang', 'Philip S. Yu'), 3), (('Jiawei Han 0001', 'Meng Qu'), 3), (('Meng Qu', 'Xiang Ren 0001'), 3), (('Charu C. Aggarwal', 'Yanjie Fu'), 3), (('Isabel Valera', 'Manuel Gomez-Rodriguez'), 3), (('Jiliang Tang', 'Yi Chang 0001'), 3), (('Chao Zhang 0014', 'Tim Hanratty'), 3), (('Jiawei Han 0001', 'Tim Hanratty'), 3), (('Quan Yuan 0001', 'Tim Hanratty'), 3), (('Philip S. Yu', 'Xiaokai Wei'), 3), (('Jon M. Kleinberg', 'Rahmtin Rotabi'), 3), (('Min Zhang 0006', 'Shaoping Ma'), 3), (('Min Zhang 0006', 'Yiqun Liu 0001'), 3), (('Shaoping Ma', 'Yiqun Liu 0001'), 3), (('Huan Liu 0001', 'Jiliang Tang'), 3), (('Martin Ester', 'Xin Wang 0019'), 3), (('Elke A. Rundensteiner', 'Yizhou Yan'), 3), (('Lei Cao 0004', 'Yizhou Yan'), 3), (('Chuanren Liu', 'Hui Xiong 0001'), 3), (('Nitesh V. Chawla', 'Yuxiao Dong'), 3), (('Bryan Hooi', 'Christos Faloutsos'), 3), (('Enhong Chen', 'Qi Liu 0003'), 3), (('Ioannis Konstantinou', 'Nectarios Koziris'), 3), (('Jiebo Luo', 'Xuefeng Peng'), 3), (('Alan Cullen', 'Seraphin B. Calo'), 3), (('Allan N. Zhang', 'Wenjing Yan'), 3), (('Arnold P. Boedihardjo', 'Chang-Tien Lu'), 3), (('Arnold P. Boedihardjo', 'Liang Zhao 0002'), 3), (('Arnold P. Boedihardjo', 'Xuchao Zhang'), 3), (('Chang-Tien Lu', 'Liang Zhao 0002'), 3), (('Chang-Tien Lu', 'Xuchao Zhang'), 3), (('Liang Zhao 0002', 'Xuchao Zhang'), 3), (('Hendrik F. Hamann', 'Theodore G. van Kessel'), 3), (('Raghava Rao Mukkamala', 'Ravi Vatrapu'), 3), (('Lionel M. Ni', 'Qiong Luo 0001'), 3), (('Daniel Muller', 'Yiea-Funk Te'), 3), (('Aaron Harwood', 'Shanika Karunasekera'), 3), (('Dhabaleswar K. Panda', 'Xiaoyi Lu'), 3), (('Berkay Aydin', 'Rafal A. Angryk'), 3), (('Rafal A. Angryk', 'Soukaina Filali Boubrahimi'), 3), (('Wei-Shih Yang', 'Xiaohua Hu 0001'), 3), (('Wei-Shih Yang', 'Xinli Yu'), 3), (('Wei-Shih Yang', 'Zheng Chen 0010'), 3), (('Xiaohua Hu 0001', 'Xinli Yu'), 3), (('Xiaohua Hu 0001', 'Zheng Chen 0010'), 3), (('Xinli Yu', 'Zheng Chen 0010'), 3), (('Daisaku Yokoyama', 'Masashi Toyoda'), 3), (('Hui Xiong 0001', 'Yanchi Liu'), 3), (('Liangjie Hong', 'Yue Shi'), 3), (('Hiroyuki Kitagawa', 'Toshiyuki Amagasa'), 3), (('Akira Ishii', 'Yasuko Kawahata'), 3), (('Justin Zhan', 'Matin Pirouz'), 3), (('Justin Zhan', 'Shahab Tayeb'), 3), (('Justin Zhan', 'Shahram Latifi'), 3), (('Matin Pirouz', 'Shahab Tayeb'), 3), (('Matin Pirouz', 'Shahram Latifi'), 3), (('Shahab Tayeb', 'Shahram Latifi'), 3), (('Markus Strohmaier', 'Philipp Singer'), 3), (('Huawei Shen', 'Wentao Ouyang'), 3), (('Huawei Shen', 'Xueqi Cheng'), 3), (('Wentao Ouyang', 'Xueqi Cheng'), 3), (('Jie Wang 0005', 'Jieping Ye'), 2), (('Inci M. Baytas', 'Jiayu Zhou'), 2), (('Eamonn J. Keogh', 'Hoang Anh Dau'), 2), (('Ben Y. Zhao', 'Shiliang Tang'), 2), (('Ben Y. Zhao', 'Xinyi Zhang'), 2), (('Haitao Zheng 0001', 'Shiliang Tang'), 2), (('Haitao Zheng 0001', 'Xinyi Zhang'), 2), (('Chaochao Chen 0001', 'Jun Zhou 0011'), 2), (('Chaochao Chen 0001', 'Xiaolong Li 0005'), 2), ( ...

# %%
# find most frequent pairs of authors for 2018
count_2018  = Counter()
for sub in list_2018:
    if len(list_2018) < 2:
        continue
    sub.sort()
    for comb in combinations(sub,2):
        count_2018[comb] += 1

print(count_2018.most_common())
# Out:
# [(('Atsuyuki Morishima', 'Masaki Matsubara'), 7), (('Donald D. Cowan', 'Paulo S. C. Alencar'), 6), (('Shaoping Ma', 'Yiqun Liu 0001'), 6), (('Enhong Chen', 'Qi Liu 0003'), 5), (('Peng Cui 0001', 'Wenwu Zhu 0001'), 5), (('Fuzheng Zhang', 'Xing Xie 0001'), 5), (('Chao Zhang 0014', 'Jiawei Han 0001'), 5), (('Tommy Dang', 'Vung Pham'), 5), (('Min Zhang 0006', 'Shaoping Ma'), 5), (('Min Zhang 0006', 'Yiqun Liu 0001'), 5), (('Anderson C. A. Nascimento', 'Martine De Cock'), 4), (('Haewoon Kwak', 'Jisun An'), 4), (('Haewoon Kwak', 'Soon-Gyo Jung'), 4), (('Jisun An', 'Soon-Gyo Jung'), 4), (('Jing Gao 0004', 'Lu Su'), 4), (('Fenglong Ma', 'Jing Gao 0004'), 4), (('Haifeng Chen', 'Wei Cheng 0002'), 4), (('Siu Cheung Hui', 'Yi Tay'), 4), (('Jiaming Shen', 'Jiawei Han 0001'), 4), (('Jacqueline C. K. Lam', 'Victor O. K. Li'), 4), (('Chenwei Zhang', 'Philip S. Yu'), 4), (('Lexing Xie', 'Marian-Andrei Rizoiu'), 4), (('Hao Wang 0005', 'Hongzhi Yin'), 3), (('Ninghao Liu', 'Xia Hu'), 3), (('Anderson C. A. Nascimento', 'Rafael Dowsley'), 3), (('Martine De Cock', 'Rafael Dowsley'), 3), (('Philip S. Yu', 'Vahid Noroozi'), 3), (('Jian Pei', 'Wenwu Zhu 0001'), 3), (('Peng Cui 0001', 'Xiao Wang 0017'), 3), (('Wenwu Zhu 0001', 'Xiao Wang 0017'), 3), (('Bernard J. Jansen', 'Haewoon Kwak'), 3), (('Bernard J. Jansen', 'Jisun An'), 3), (('Bernard J. Jansen', 'Soon-Gyo Jung'), 3), (('Fang Chen 0001', 'Yang Wang 0002'), 3), (('Han Li', 'Kun Gai'), 3), (('James B. Wendt', 'Marc Najork'), 3), (('Enhong Chen', 'Zhenya Huang'), 3), (('Qi Liu 0003', 'Zhenya Huang'), 3), (('Feiping Nie 0001', 'Xuelong Li'), 3), (('Chenglin Miao', 'Lu Su'), 3), (('Lu Su', 'Yaliang Li'), 3), (('Jing Gao 0004', 'Qi Li 0012'), 3), (('Najmeh Miramirkhani', 'Nick Nikiforakis'), 3), (('Luu Anh Tuan', 'Siu Cheung Hui'), 3), (('Luu Anh Tuan', 'Yi Tay'), 3), (('Jun Zhou 0011', 'Xiaolong Li 0005'), 3), (('Xin Liang 0001', 'Zizhong Chen'), 3), (('Hanghang Tong', 'Nan Cao'), 3), (('Hanghang Tong', 'Yinglong Xia'), 3), (('Nan Cao', 'Yinglong Xia'), 3), (('Boguslaw Obara', 'Georgios Theodoropoulos 0001'), 3), (('Haewoon Kwak', 'Joni Salminen'), 3), (('Jisun An', 'Joni Salminen'), 3), (('Joni Salminen', 'Soon-Gyo Jung'), 3), (('Jure Leskovec', 'Tim Althoff'), 3), (('Konstantina Bereta', 'Manolis Koubarakis'), 3), (('Leila Jalali', 'Rahul Biswas'), 3), (('Jiaxin Mao', 'Yiqun Liu 0001'), 3), (('Can Wang 0001', 'Martin Ester'), 3), (('Tommy Dang', 'Vinh T. Nguyen'), 3), (('Vinh T. Nguyen', 'Vung Pham'), 3), (('Albert Bifet', 'Talel Abdessalem'), 3), (('Carlos Lucena', 'Paulo S. C. Alencar'), 3), (('Lei Zheng 0001', 'Philip S. Yu'), 3), (('Philip S. Yu', 'Sihong Xie'), 3), (('Rong Wen', 'Wenjing Yan'), 3), (('Haozhen Zhao', 'Nathaniel Huber-Fliflet'), 3), (('Di Niu', 'Kunfeng Lai'), 3), (('Di Niu', 'Yu Xu'), 3), (('Kunfeng Lai', 'Yu Xu'), 3), (('Jiajun Bu', 'Martin Ester'), 3), (('Hongyang Gao', 'Shuiwang Ji'), 3), (('Chao Zhang 0014', 'Jiaming Shen'), 3), (('Shangsong Liang', 'Zhaochun Ren'), 3), (('Shuiwang Ji', 'Zhengyang Wang'), 3), (('Jiawei Han 0001', 'Xiang Ren 0001'), 3), (('Arild Waaler', 'Evgeny Kharlamov'), 3), (('Lu-An Tang', 'Zhengzhang Chen'), 3), (('Lu-An Tang', 'Zhichun Li'), 3), (('Zhengzhang Chen', 'Zhichun Li'), 3), (('Chao Huang 0001', 'Nitesh V. Chawla'), 3), (('Haruo Hayashi', 'Kei Horie'), 2), (('Haruo Hayashi', 'Keiko Tamura'), 2), (('Haruo Hayashi', 'Munenari Inoguchi'), 2), (('Haruo Hayashi', 'Ryota Hamamoto'), 2), (('Kei Horie', 'Keiko Tamura'), 2), (('Kei Horie', 'Munenari Inoguchi'), 2), (('Kei Horie', 'Ryota Hamamoto'), 2), (('Keiko Tamura', 'Munenari Inoguchi'), 2), (('Keiko Tamura', 'Ryota Hamamoto'), 2), (('Munenari Inoguchi', 'Ryota Hamamoto'), 2), (('Branislav Kveton', 'S. Muthukrishnan'), 2), (('Hongwei Wang 0004', 'Miao Zhao'), 2), (('Hunter Jackson', 'Katherine Scott'), 2), (('Hunter Jackson', 'Venkata. N. P. Vemuri'), 2), (('Katherine Scott', 'Venkata. N. P. Vemuri'), 2), (('Ed H. Chi', 'Sagar Jain'), 2), (('Ilya Safro', 'Justin Sybrandt'), 2), (('Daniel Yue Zhan ...

# %%
# find most frequent pairs of authors for 2019
count_2019  = Counter()
for sub in list_2019:
    if len(list_2019) < 2:
        continue
    sub.sort()
    for comb in combinations(sub,2):
        count_2019[comb] += 1

print(count_2019.most_common())
# Out:
# [(('Min Zhang 0006', 'Shaoping Ma'), 9), (('Min Zhang 0006', 'Yiqun Liu 0001'), 9), (('Shaoping Ma', 'Yiqun Liu 0001'), 9), (('Chuhan Wu', 'Fangzhao Wu'), 8), (('Chuhan Wu', 'Xing Xie 0001'), 8), (('Chuhan Wu', 'Yongfeng Huang 0001'), 8), (('Fangzhao Wu', 'Xing Xie 0001'), 8), (('Fangzhao Wu', 'Yongfeng Huang 0001'), 8), (('Xing Xie 0001', 'Yongfeng Huang 0001'), 8), (('Peng Cui 0001', 'Wenwu Zhu 0001'), 7), (('Enhong Chen', 'Qi Liu 0003'), 6), (('Chuan Shi', 'Yanfang Ye'), 6), (('Chuhan Wu', 'Junxin Liu'), 6), (('Fangzhao Wu', 'Junxin Liu'), 6), (('Junxin Liu', 'Xing Xie 0001'), 6), (('Junxin Liu', 'Yongfeng Huang 0001'), 6), (('Dingqi Yang', 'Philippe Cudré-Mauroux'), 5), (('Chao Huang 0001', 'Nitesh V. Chawla'), 5), (('Hengshu Zhu', 'Hui Xiong 0001'), 5), (('Huiyuan Chen', 'Jing Li 0002'), 5), (('Weinan Zhang 0001', 'Yong Yu 0001'), 5), (('Jiaxin Mao', 'Min Zhang 0006'), 5), (('Jiaxin Mao', 'Shaoping Ma'), 5), (('Jiaxin Mao', 'Yiqun Liu 0001'), 5), (('Fan Zhou 0002', 'Goce Trajcevski'), 5), (('Fan Zhou 0002', 'Kunpeng Zhang'), 5), (('Fan Zhou 0002', 'Ting Zhong'), 5), (('Goce Trajcevski', 'Kunpeng Zhang'), 5), (('Goce Trajcevski', 'Ting Zhong'), 5), (('Kunpeng Zhang', 'Ting Zhong'), 5), (('Bo Dong', 'Huan He'), 5), (('Bo Dong', 'Qinghua Zheng'), 5), (('Huan He', 'Qinghua Zheng'), 5), (('Hongxia Yang', 'Jingren Zhou'), 5), (('Guobin Wu', 'Jieping Ye'), 4), (('Guiying Tang', 'Xiaoqin Zhang 0002'), 4), (('Atsuyuki Morishima', 'Masaki Matsubara'), 4), (('Catherine D. Schuman', 'Robert M. Patton'), 4), (('Catherine D. Schuman', 'Thomas E. Potok'), 4), (('Robert M. Patton', 'Thomas E. Potok'), 4), (('Miao Fan', 'Ping Li 0001'), 4), (('Dawei Yin', 'Jiashu Zhao'), 4), (('Shangsong Liang', 'Zaiqiao Meng'), 4), (('Elke A. Rundensteiner', 'Xiangnan Kong'), 4), (('Guanjie Zheng', 'Kai Xu'), 4), (('Guanjie Zheng', 'Zhenhui Li'), 4), (('Hua Wei 0001', 'Zhenhui Li'), 4), (('Kai Xu', 'Zhenhui Li'), 4), (('Chao Huang 0001', 'Xian Wu'), 4), (('Nitesh V. Chawla', 'Xian Wu'), 4), (('Azim Ahmadzadeh', 'Rafal A. Angryk'), 4), (('Manolis K. Georgoulis', 'Rafal A. Angryk'), 4), (('Ioannis Konstantinou', 'Nectarios Koziris'), 4), (('Barbara Korousic-Seljak', 'Tome Eftimov'), 4), (('Bashar Barmada', 'Guillermo Ramírez-Prado'), 4), (('Bashar Barmada', 'Veronica Liesaputra'), 4), (('Guillermo Ramírez-Prado', 'Veronica Liesaputra'), 4), (('Gangmin Li', 'Jiayi Zhu'), 4), (('Gangmin Li', 'Junkun Peng'), 4), (('Gangmin Li', 'Pin Ni'), 4), (('Gangmin Li', 'Xuming Bai'), 4), (('Gangmin Li', 'Yuming Li'), 4), (('Gangmin Li', 'Zhenjin Dai'), 4), (('Jiayi Zhu', 'Junkun Peng'), 4), (('Jiayi Zhu', 'Pin Ni'), 4), (('Jiayi Zhu', 'Xuming Bai'), 4), (('Jiayi Zhu', 'Yuming Li'), 4), (('Jiayi Zhu', 'Zhenjin Dai'), 4), (('Junkun Peng', 'Pin Ni'), 4), (('Junkun Peng', 'Xuming Bai'), 4), (('Junkun Peng', 'Yuming Li'), 4), (('Junkun Peng', 'Zhenjin Dai'), 4), (('Pin Ni', 'Xuming Bai'), 4), (('Pin Ni', 'Yuming Li'), 4), (('Pin Ni', 'Zhenjin Dai'), 4), (('Xuming Bai', 'Yuming Li'), 4), (('Xuming Bai', 'Zhenjin Dai'), 4), (('Yuming Li', 'Zhenjin Dai'), 4), (('Jieping Ye', 'Zhiwei Qin'), 4), (('Fenglong Ma', 'Jing Gao 0004'), 4), (('Latifur Khan', 'Yang Gao 0027'), 4), (('Heng Huang', 'Jian Pei'), 4), (('Di Niu', 'Kunfeng Lai'), 4), (('Di Niu', 'Yu Xu'), 4), (('Kunfeng Lai', 'Yu Xu'), 4), (('Chengxi Zang', 'Peng Cui 0001'), 4), (('Chengxi Zang', 'Wenwu Zhu 0001'), 4), (('Hongxia Yang', 'Jie Tang 0001'), 4), (('Depeng Jin', 'Yong Li 0008'), 4), (('James Caverlee', 'Majid Alfifi'), 3), (('James Caverlee', 'Parisa Kaghazgaran'), 3), (('Majid Alfifi', 'Parisa Kaghazgaran'), 3), (('Catherine D. Schuman', 'Derek C. Rose'), 3), (('Catherine D. Schuman', 'J. Travis Johnston'), 3), (('Catherine D. Schuman', 'Steven R. Young'), 3), (('Derek C. Rose', 'J. Travis Johnston'), 3), (('Derek C. Rose', 'Robert M. Patton'), 3), (('Derek C. Rose', 'Steven R. Young'), 3), (('Derek C. Rose', 'Thomas E. Potok'), 3), (('J. Travis Johnston', 'Robert M. Patton'), 3), (('J. Travis Johnston', 'Steven R ...

# %%
# find most frequent pairs of authors for 2020
count_2020  = Counter()
for sub in list_2020:
    if len(list_2020) < 2:
        continue
    sub.sort()
    for comb in combinations(sub,2):
        count_2020[comb] += 1

print(count_2020.most_common())
# Out:
# [(('Ji-Rong Wen', 'Wayne Xin Zhao'), 7), (('Jeremy Blackburn', 'Savvas Zannettou'), 7), (('Ruiming Tang', 'Xiuqiang He'), 6), (('Berkay Aydin', 'Rafal A. Angryk'), 5), (('Christos Faloutsos', 'Xin Luna Dong'), 5), (('Suhang Wang', 'Xianfeng Tang'), 5), (('Cao Xiao', 'Jimeng Sun'), 5), (('Fuzheng Zhang', 'Zhongyuan Wang'), 5), (('Huan Liu 0001', 'Kai Shu'), 5), (('Jiawei Han 0001', 'Jiaxin Huang'), 5), (('Jiawei Han 0001', 'Yu Meng 0001'), 5), (('Jiaxin Huang', 'Yu Meng 0001'), 5), (('Donald Metzler', 'Zhen Qin 0002'), 5), (('Elke A. Rundensteiner', 'Xiangnan Kong'), 5), (('Barbara Korousic-Seljak', 'Tome Eftimov'), 5), (('Dhaval Patel', 'Shrey Shrivastava'), 5), (('Krisztian Balog', 'Shuo Zhang 0006'), 4), (('Michael N. Gubanov', 'Rituparna Khan'), 4), (('Jun Luo 0007', 'Xun Zhou'), 4), (('Jun Luo 0007', 'Yanhua Li'), 4), (('Xun Zhou', 'Yanhua Li'), 4), (('Anli Ji', 'Rafal A. Angryk'), 4), (('Berkay Aydin', 'Manolis K. Georgoulis'), 4), (('Manolis K. Georgoulis', 'Rafal A. Angryk'), 4), (('Hui Xiong 0001', 'Jingbo Zhou'), 4), (('Christos Faloutsos', 'Tong Zhao'), 4), (('Tong Zhao', 'Xin Luna Dong'), 4), (('Christian Böhm', 'Claudia Plant'), 4), (('Weinan Zhang 0001', 'Yong Yu 0001'), 4), (('Qing He 0003', 'Xiang Ao'), 4), (('Jyun-Yu Jiang', 'Wei Wang 0010'), 4), (('Changjie Fan', 'Jianrong Tao'), 4), (('Changjie Fan', 'Runze Wu'), 4), (('Jianrong Tao', 'Runze Wu'), 4), (('Mingming Sun', 'Ping Li 0001'), 4), (('Fengli Xu', 'Yong Li 0008'), 4), (('Dawei Zhou', 'Jingrui He'), 4), (('Hanghang Tong', 'Si Zhang'), 4), (('Ji-Rong Wen', 'Kun Zhou'), 4), (('Kun Zhou', 'Wayne Xin Zhao'), 4), (('Peiquan Jin', 'Shouhong Wan'), 4), (('Carlos Ordonez 0001', 'Ladjel Bellatreche'), 4), (('Haifeng Wang', 'Jizhou Huang'), 4), (('Bo Long', 'Huiji Gao'), 4), (('Bo Long', 'Weiwei Guo'), 4), (('Huiji Gao', 'Weiwei Guo'), 4), (('Chao Yi', 'Yixin Chen'), 4), (('Dhaval Patel', 'Nianjun Zhou'), 4), (('Nianjun Zhou', 'Shrey Shrivastava'), 4), (('Jiawei Xu', 'Li Zhao 0005'), 3), (('Enhong Chen', 'Hui Xiong 0001'), 3), (('Mark Coates', 'Ruiming Tang'), 3), (('Mark Coates', 'Yingxue Zhang'), 3), (('Ruiming Tang', 'Yingxue Zhang'), 3), (('Peng Cui 0001', 'Zheyan Shen'), 3), (('Feng Ji', 'Haiqing Chen'), 3), (('Defu Lian', 'Enhong Chen'), 3), (('Junzhou Huang', 'Yu Rong'), 3), (('Aidong Zhang', 'Jianhui Sun'), 3), (('Anli Ji', 'Berkay Aydin'), 3), (('Carlos Ordonez 0001', 'Sikder Tahsin Al-Amin'), 3), (('Andrey Kan', 'Christos Faloutsos'), 3), (('Andrey Kan', 'Tong Zhao'), 3), (('Andrey Kan', 'Xin Luna Dong'), 3), (('Christos Faloutsos', 'Jiawei Han 0001'), 3), (('Jiawei Han 0001', 'Xin Luna Dong'), 3), (('Jiawei Han 0001', 'Yuning Mao'), 3), (('Meng Jiang 0001', 'Nitesh V. Chawla'), 3), (('Xiuqiang He', 'Zhenguo Li'), 3), (('Suhang Wang', 'Yiwei Sun'), 3), (('Yihui Zhang', 'Yixin Chen'), 3), (('Duen Horng Chau', 'Scott Freitas'), 3), (('Azim Ahmadzadeh', 'Rafal A. Angryk'), 3), (('Quanming Yao', 'Yong Li 0008'), 3), (('Chang Zhou', 'Hongxia Yang'), 3), (('Jiliang Tang', 'Wei Jin'), 3), (('Gautam Srivastava', 'Jerry Chun-Wei Lin'), 3), (('Jiayu Tang', 'Jinghua Feng'), 3), (('Jiayu Tang', 'Qing He 0003'), 3), (('Jiayu Tang', 'Qiwei Zhong'), 3), (('Jiayu Tang', 'Xiang Ao'), 3), (('Jinghua Feng', 'Qing He 0003'), 3), (('Jinghua Feng', 'Qiwei Zhong'), 3), (('Jinghua Feng', 'Xiang Ao'), 3), (('Qing He 0003', 'Qiwei Zhong'), 3), (('Qiwei Zhong', 'Xiang Ao'), 3), (('Charles C. Tappert', 'Manoj Muniswamaiah'), 3), (('Charles C. Tappert', 'Tilak Agerwala'), 3), (('Manoj Muniswamaiah', 'Tilak Agerwala'), 3), (('Hui Xiong 0001', 'Tong Xu'), 3), (('Huzefa Rangwala', 'Yue Ning'), 3), (('Jian Lou 0001', 'Li Xiong 0001'), 3), (('Changjie Fan', 'Liang Chen'), 3), (('Jianrong Tao', 'Liang Chen'), 3), (('Liang Chen', 'Runze Wu'), 3), (('Chengxi Zang', 'Fei Wang'), 3), (('Kuansan Wang', 'Yuxiao Dong'), 3), (('Mounia Lalmas', 'Rishabh Mehrotra'), 3), (('Min Zhang 0006', 'Shaoping Ma'), 3), (('Min Zhang 0006', 'Yiqun Liu 0001'), 3), (('Shaoping Ma', 'Yiqun Liu 0001'), 3), (('Emi ...

# %%
# convert dictionary with pairs and their weight for 2016 to data frame 
pairs_2016 = pd.DataFrame(count_2016.items(), columns=['Authors','weight']) 
split_2016 = pd.DataFrame(pairs_2016['Authors'].tolist(), index=pairs_2016.index, columns=['From','To'])
df_2016 = split_2016.join(pairs_2016['weight'])
df_2016
# Out:
#                 From               To  weight
# 0      Huan Liu 0001     Jiliang Tang       6
# 1      Huan Liu 0001      Suhang Wang       3
# 2      Huan Liu 0001  Suhas Ranganath       1
# 3      Huan Liu 0001           Xia Hu       3
# 4       Jiliang Tang      Suhang Wang       3
# ...              ...              ...     ...
# 9661     Hua Wu 0003   Xiangyang Zhou       1
# 9662     Hua Wu 0003      Yiping Song       1
# 9663         Rui Yan   Xiangyang Zhou       1
# 9664         Rui Yan      Yiping Song       1
# 9665  Xiangyang Zhou      Yiping Song       1
#
# [9666 rows x 3 columns]

# %%
# convert dictionary with pairs and their weight for 2017 to data frame 
pairs_2017 = pd.DataFrame(count_2017.items(), columns=['Authors','weight']) 
split_2017 = pd.DataFrame(pairs_2017['Authors'].tolist(), index=pairs_2017.index, columns=['From','To'])
df_2017 = split_2017.join(pairs_2017['weight'])
df_2017
# Out:
#                            From                   To  weight
# 0      Dennis M. M. Schunselaar      Hajo A. Reijers       1
# 1      Dennis M. M. Schunselaar       Henrik Leopold       1
# 2      Dennis M. M. Schunselaar  Marzieh Bakhshandeh       1
# 3               Hajo A. Reijers       Henrik Leopold       1
# 4               Hajo A. Reijers  Marzieh Bakhshandeh       1
# ...                         ...                  ...     ...
# 10903              Naoto Ohsaka       Yuichi Yoshida       1
# 10904               Mong-Li Lee         Wee-Yong Lim       1
# 10905               Mong-Li Lee            Wynne Hsu       1
# 10906              Wee-Yong Lim            Wynne Hsu       1
# 10907       Lars Schmidt-Thieme    Nghia Duong-Trung       1
#
# [10908 rows x 3 columns]

# %%
# convert dictionary with pairs and their weight for 2018 to data frame 
pairs_2018 = pd.DataFrame(count_2018.items(), columns=['Authors','weight']) 
split_2018 = pd.DataFrame(pairs_2018['Authors'].tolist(), index=pairs_2018.index, columns=['From','To'])
df_2018 = split_2018.join(pairs_2018['weight'])
df_2018
# Out:
#                     From                   To  weight
# 0             Jing Zhang      Xindong Wu 0001       1
# 1             Jiaheng Lu      Pengfei Xu 0004       1
# 2         David Renaudie     Maria A. Zuluaga       1
# 3         David Renaudie  Rodrigo Acuna-Agost       1
# 4       Maria A. Zuluaga  Rodrigo Acuna-Agost       1
# ...                  ...                  ...     ...
# 12617          Nannan Gu    Tianhao Wang 0006       1
# 12618          Nannan Gu   Xiaoqin Zhang 0002       1
# 12619       Qianqian Liu    Tianhao Wang 0006       1
# 12620       Qianqian Liu   Xiaoqin Zhang 0002       1
# 12621  Tianhao Wang 0006   Xiaoqin Zhang 0002       1
#
# [12622 rows x 3 columns]

# %%
# convert dictionary with pairs and their weight for 2019 to data frame 
pairs_2019 = pd.DataFrame(count_2019.items(), columns=['Authors','weight']) 
split_2019 = pd.DataFrame(pairs_2019['Authors'].tolist(), index=pairs_2019.index, columns=['From','To'])
df_2019 = split_2019.join(pairs_2019['weight'])
df_2019
# Out:
#                         From               To  weight
# 0                Chaozhuo Li     Feiran Huang       1
# 1                Chaozhuo Li   Lei Zheng 0001       1
# 2                Chaozhuo Li     Philip S. Yu       2
# 3                Chaozhuo Li    Senzhang Wang       2
# 4                Chaozhuo Li       Zhoujun Li       2
# ...                      ...              ...     ...
# 18066           Qinyong Wang         Zi Huang       1
# 18067  Quoc Viet Hung Nguyen         Zi Huang       1
# 18068        Cecilia Mascolo        Xiao Zhou       1
# 18069        Cecilia Mascolo  Zhongxiang Zhao       1
# 18070              Xiao Zhou  Zhongxiang Zhao       1
#
# [18071 rows x 3 columns]

# %%
# convert dictionary with pairs and their weight for 2020 to data frame 
pairs_2020 = pd.DataFrame(count_2020.items(), columns=['Authors','weight']) 
split_2020 = pd.DataFrame(pairs_2020['Authors'].tolist(), index=pairs_2020.index, columns=['From','To'])
df_2020 = split_2020.join(pairs_2020['weight'])
df_2020
# Out:
#                From             To  weight
# 0      Donghyun Ahn   Hyunjoo Yang       1
# 1      Donghyun Ahn   Jeasurk Yang       1
# 2      Donghyun Ahn      Jihee Kim       1
# 3      Donghyun Ahn   Meeyoung Cha       1
# 4      Donghyun Ahn  Sangyoon Park       1
# ...             ...            ...     ...
# 18961       Ming Tu    Yuxuan Wang       1
# 18962       Ming Tu    Zishun Feng       1
# 18963       Rui Xia    Yuxuan Wang       1
# 18964       Rui Xia    Zishun Feng       1
# 18965   Yuxuan Wang    Zishun Feng       1
#
# [18966 rows x 3 columns]

# %% [markdown]
# ## Extract to csv files

# %%
# Create csv files for each year
df_2016.to_csv('authors_2016.csv', index=False)
df_2017.to_csv('authors_2017.csv', index=False)
df_2018.to_csv('authors_2018.csv', index=False)
df_2019.to_csv('authors_2019.csv', index=False)
df_2020.to_csv('authors_2020.csv', index=False)
